# %% [markdown]
# # Meta-Analysis v1: Multi-Agent vs Single-Agent LLM Systems
# **Author:** Xinyu Yang (r1020926), KU Leuven
# **RQ1:** Do multi-agent LLM systems outperform single-agent baselines on benchmark accuracy?

# %%
import sys, json
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

sys.path.insert(0, str(Path.cwd().parent))
from src.data_io import load_verified, DATA_VERIFIED, REPORT_ASSETS
from src.effect_sizes import compute_effect_sizes
from src.pooling import random_effects
from src.heterogeneity import baujat, cooks_distance, hat_values, leave_one_out
from src.moderators import subgroup_analysis, meta_regression
from src.publication_bias import egger_test, begg_test, trim_and_fill, p_curve
from src.sensitivity import run_all_sensitivity
from src.plots import (forest_plot, forest_plot_interactive, funnel_plot,
                       baujat_plot, subgroup_forest, bubble_plot, prisma_flow)
from src.reporting import format_pooled, descriptives_table, sensitivity_table

REPORT_ASSETS.mkdir(parents=True, exist_ok=True)
print("All modules loaded.")
# Out:
# All modules loaded.

# %% [markdown]
# ## Load & Sanity Check

# %%
df = load_verified()
rob = pd.read_csv(DATA_VERIFIED / "risk-of-bias.csv")
with open(Path.cwd().parent / "data" / "extracted" / "prisma-counts.json") as f:
    prisma_counts = json.load(f)

print(f"Studies loaded: {len(df)}")
print(f"Columns: {list(df.columns)}")
print(f"\nYear distribution:\n{df['year'].value_counts().sort_index()}")
print(f"\nArchitecture distribution:\n{df['architecture'].value_counts()}")
print(f"\nCompute parity:\n{df['compute-parity-flag'].value_counts()}")
df.head(10)
# Out:
# Studies loaded: 41
# Columns: ['study-id', 'citation-key', 'year', 'backbone-model', 'architecture', 'n-agents', 'task-category', 'benchmark-name', 'n-items', 'n-correct-ma', 'n-correct-sa', 'compute-parity-flag', 'compute-ratio-ma-to-sa', 'source-table-or-figure', 'audit-status']
#
# Year distribution:
# year
# 2023     1
# 2024    11
# 2025    16
# 2026    13
# Name: count, dtype: int64
#
# Architecture distribution:
# architecture
# debate              20
# cooperation          9
# hierarchy            6
# role-play            2
# verifier-critic      2
# planner-executor     1
# moa                  1
# Name: count, dtype: int64
#
# Compute parity:
# compute-parity-flag
# no         25
# yes         9
# unclear     7
# Name: count, dtype: int64
#   study-id   citation-key  year  \
# 0     S001         Du2023  2023
# 1     S002       Qian2024  2024
# 2     S003      Liang2024  2024
# 3     S004      Huang2024  2024
# 4     S005        Xue2025  2025
# 5     S006       Yang2025  2025
# 6     S007      Islam2024  2024
# 7     S008       Hong2024  2024
# 8     S009     Zhang2024b  2024
# 9     S010  Benkovich2026  2026
#
#                                       backbone-model      architecture  \
# 0                                  ChatGPT (GPT-3.5)            debate
# 1                                      GPT-3.5-Turbo         role-play
# 2                                      GPT-3.5-Turbo       cooperation
# 3                                              GPT-4       cooperation
# 4  Gemini 2.5 Pro / GPT-5 / Grok 4 / Claude Sonnet 4       cooperation
# 5                                      GPT-3.5-Turbo       cooperation
# 6                                              GPT-4  planner-executor
# 7                                              GPT-4         hierarchy
# 8                                              mixed       cooperation
# 9                                              GPT-5         role-play
#
#    n-agents task-category        benchmark-name  n-items  n-correct-ma  \
# 0         3          math                 GSM8K     1319          1121
# 1         3          code           SoftwareDev       70             1
# 2         3    evaluation  Counter-Intuitive AR      200            74
# 3         3          code             HumanEval      164           158
# 4         3         other          GPQA-Diamond      198           172
# 5         3          code             HumanEval      164           135
# 6         4          code             HumanEval      164           154
# 7         3          code             HumanEval      164           141
# 8         3          code        SWE-bench Lite      300           103
# 9         5          code         SWE-bench 500      500           360
#
#    n-correct-sa compute-parity-flag compute-ratio-ma-to-sa  \
# 0          1016                  no                     NR
# 1             1                  no                     NR
# 2            56                  no                     NR
# 3           148                  no                     NR
# 4           170                  no                     NR
# 5           125             unclear                     NR
# 6           145                  no                     NR
# 7           110                  no                     NR
# 8            82             unclear                     NR
# 9           325                 yes                     NR
#
#          source-table-or-figure        audit-status
# 0         Table/Fig from Du2023           unaudited
# 1       Table/Fig from Qian2024           unaudited
# 2      Table/Fig from Liang2024           unaudited
# 3      Table/Fig from Huang2024           unaudited
# 4        Table/Fig from Xue2025            verified
# 5       Table/Fig from Yang2025           unaudited
# 6      Table/Fig from Islam2024  verified-corrected
# 7       Table/Fig from Hong2024           unaudited
# 8     Table/Fig from Zhang2024b  verified-corrected
# 9  Table/Fig from Benkovich2026           unaudited

# %% [markdown]
# ## Effect Sizes

# %%
df = compute_effect_sizes(df)
print(f"Effect sizes computed for {len(df)} studies")
print(f"\nLog-OR (yi) summary:\n{df['yi'].describe()}")
print(f"\nCohen's h summary:\n{df['h'].describe()}")
print(f"\nStudies with MA advantage (yi > 0): {(df['yi'] > 0).sum()}")
print(f"Studies with SA advantage (yi < 0): {(df['yi'] < 0).sum()}")
df[["study-id", "citation-key", "architecture", "benchmark-name", "yi", "sei", "h"]].round(3)
# Out:
# Effect sizes computed for 41 studies
#
# Log-OR (yi) summary:
# count    41.000000
# mean      0.500179
# std       0.768646
# min      -2.251240
# 25%       0.194300
# 50%       0.364627
# 75%       0.679057
# max       2.411784
# Name: yi, dtype: float64
#
# Cohen's h summary:
# count    41.000000
# mean      0.199201
# std       0.342588
# min      -1.077335
# 25%       0.096583
# 50%       0.155764
# 75%       0.246310
# max       1.186914
# Name: h, dtype: float64
#
# Studies with MA advantage (yi > 0): 37
# Studies with SA advantage (yi < 0): 3
#    study-id    citation-key      architecture  \
# 0      S001          Du2023            debate
# 1      S002        Qian2024         role-play
# 2      S003       Liang2024       cooperation
# 3      S004       Huang2024       cooperation
# 4      S005         Xue2025       cooperation
# 5      S006        Yang2025       cooperation
# 6      S007       Islam2024  planner-executor
# 7      S008        Hong2024         hierarchy
# 8      S009      Zhang2024b       cooperation
# 9      S010   Benkovich2026         role-play
# 10     S011         Xie2025   verifier-critic
# 11     S012        Doki2024       cooperation
# 12     S013        Chen2026       cooperation
# 13     S014         Kim2024         hierarchy
# 14     S015        Tang2024            debate
# 15     S016          Li2025   verifier-critic
# 16     S017    MediHive2026            debate
# 17     S018      MedARC2025            debate
# 18     S019     Charney2026         hierarchy
# 19     S020       Ophth2026            debate
# 20     S021       MedLA2025            debate
# 21     S022         Bao2025       cooperation
# 22     S023      Ferber2025         hierarchy
# 23     S024  Topologies2026         hierarchy
# 24     S025        Chen2024         hierarchy
# 25     S026         Han2025            debate
# 26     S027         Fan2025            debate
# 27     S028          Wu2025            debate
# 28     S029        Wynn2025            debate
# 29     S030         Yao2025            debate
# 30     S031         Lin2025            debate
# 31     S032         Cui2025            debate
# 32     S033        Wang2025            debate
# 33     S034        Tian2026            debate
# 34     S035        Tran2026            debate
# 35     S036          Li2026            debate
# 36     S037          Hu2025            debate
# 37     S038         Liu2026            debate
# 38     S039        Zhou2025       cooperation
# 39     S040        Wang2024               moa
# 40     S041          Ki2025            debate
#
#                                        benchmark-name     yi    sei      h
# 0                                               GSM8K  0.523  0.101  0.204
# 1                                         SoftwareDev  0.000  1.167  0.000
# 2                                Counter-Intuitive AR  0.410  0.214  0.193
# 3                                           HumanEval  0.997  0.477  0.250
# 4                                        GPQA-Diamond  0.084  0.291  0.029
# 5                                           HumanEval  0.369  0.273  0.151
# 6                                           HumanEval  0.679  0.400  0.196
# 7                                           HumanEval  1.088  0.278  0.455
# 8                                      SWE-bench Lite  0.328  0.177  0.152
# 9                                       SWE-bench 500  0.325  0.137  0.151
# 10                                          HumanEval  1.753  0.242  0.855
# 11                                          HumanEval  1.822  0.592  0.423
# 12                                          ClassEval  1.052  0.328  0.473
# 13                                              MedQA  0.280  0.103  0.108
# 14                             MedQA (avg 9 datasets)  0.452  0.109  0.166
# 15                                        MedXpert-MM  0.281  0.127  0.130
# 16                                              MedQA  0.472  0.102  0.186
# 17                                           PubMedQA  0.231  0.092  0.100
# 18                           Clinical tasks (5 tasks)  1.282  0.408  0.483
# 19                            Ophthalmology vignettes  1.320  0.405  0.364
# 20                                      MedDDx-Expert  0.471  0.124  0.227
# 21                                    MMLU-Pro-Health  0.137  0.027  0.061
# 22                             GI oncology (20 cases)  2.412  0.752  1.187
# 23                           Rare disease (302 cases)  0.079  0.163  0.040
# 24                                     SWE-bench Lite  0.585  0.197  0.246
# 25                          Weibo21 / FakeNewsDataset  0.470  0.052  0.194
# 26                                              GSM8K  0.812  0.098  0.332
# 27                          Knight-Knave-Spy (size 4)  2.354  0.339  1.111
# 28                                               MMLU -0.543  0.029 -0.223
# 29                                      CommonsenseQA  0.084  0.118  0.029
# 30                                               MMLU  0.452  0.030  0.180
# 31  8 benchmarks (GSM-Ranges / AIME / MATH500 / St...  0.365  0.041  0.178
# 32                                               GPQA  0.203  0.202  0.101
# 33                                               MATH  0.145  0.049  0.059
# 34                                             FRAMES -0.169  0.116 -0.072
# 35  13 datasets (Knowledge / Math / Medicine / Sci...  0.076  0.042  0.036
# 36                                             LLMBar  0.308  0.172  0.125
# 37            MATH500 / AMC23 / AIME24 / AIME25 (avg)  0.194  0.040  0.097
# 38                             HiddenBench (65 tasks) -2.251  0.412 -1.077
# 39                                     AlpacaEval 2.0  0.320  0.103  0.156
# 40                                         NormAd-ETI  0.256  0.144  0.113

# %% [markdown]
# ## Descriptives

# %%
desc = descriptives_table(df)
print("Year × Architecture × Task-Category cross-tabulation:")
desc
# Out:
# Year × Architecture × Task-Category cross-tabulation:
# task-category           code  evaluation  factuality  general-knowledge  math  \
# year  architecture
# 2023  debate               0           0           0                  0     1
# 2024  cooperation          3           1           0                  0     0
#       debate               0           0           0                  0     0
#       hierarchy            2           0           0                  0     0
#       moa                  0           0           0                  0     0
#       planner-executor     1           0           0                  0     0
#       role-play            1           0           0                  0     0
# 2025  cooperation          1           0           0                  1     0
#       debate               0           1           1                  2     2
#       hierarchy            0           0           0                  0     0
#       verifier-critic      0           0           0                  0     0
# 2026  cooperation          1           0           0                  0     0
#       debate               0           0           0                  0     3
#       hierarchy            0           1           0                  0     0
#       role-play            1           0           0                  0     0
#       verifier-critic      1           0           0                  0     0
# Total                     11           3           1                  3     6
#
# task-category           medical  other  Total
# year  architecture
# 2023  debate                  0      0      1
# 2024  cooperation             0      0      4
#       debate                  1      0      1
#       hierarchy               1      0      3
#       moa                     0      1      1
#       planner-executor        0      0      1
#       role-play               0      0      1
# 2025  cooperation             0      1      3
#       debate                  1      4     11
#       hierarchy               0      1      1
#       verifier-critic         0      1      1
# 2026  cooperation             0      1      2
#       debate                  3      1      7
#       hierarchy               1      0      2
#       role-play               0      0      1
#       verifier-critic         0      0      1
# Total                         7     10     41

# %% [markdown]
# ## Primary Pooling (REML + DL Sensitivity)

# %%
yi, vi = df["yi"].values, df["vi"].values

res_reml = random_effects(yi, vi, method="reml")
res_dl = random_effects(yi, vi, method="dl")

print("=== REML Random-Effects ===")
print(format_pooled(res_reml))
print(f"\n=== DerSimonian-Laird (sensitivity) ===")
print(format_pooled(res_dl))

pooled = res_reml
# Out:
# === REML Random-Effects ===
# LOR = 0.44, 95% CI [0.26, 0.63], 95% PI [-0.68, 1.57], τ² = 0.321, I² = 98%, Q(40) = 1624.7, p = 0.0000
#
# === DerSimonian-Laird (sensitivity) ===
# LOR = 0.41, 95% CI [0.28, 0.54], 95% PI [-0.34, 1.17], τ² = 0.144, I² = 97%, Q(40) = 1494.9, p = 0.0000

# %% [markdown]
# ## Forest Plot

# %%
fig_forest = forest_plot(df.sort_values("yi"), pooled)
plt.show()
_ = forest_plot_interactive(df.sort_values("yi"), pooled)
print("Forest plots saved to report/assets/")
# Out:
# Forest plots saved to report/assets/

# %% [markdown]
# ## Heterogeneity Diagnostics

# %%
qi, influence = baujat(yi, vi, pooled["tau2"])
fig_baujat = baujat_plot(qi, influence, df["citation-key"].tolist())
plt.show()

cooks = cooks_distance(yi, vi, pooled["tau2"])
hats = hat_values(vi, pooled["tau2"])
print(f"Top 5 Cook's distance:\n{df.iloc[np.argsort(-cooks)[:5]][['citation-key', 'yi']].assign(cooks=np.sort(cooks)[::-1][:5]).to_string()}")
print(f"\nTop 5 hat values:\n{df.iloc[np.argsort(-hats)[:5]][['citation-key', 'yi']].assign(hat=np.sort(hats)[::-1][:5]).to_string()}")
# Out:
# Top 5 Cook's distance:
#    citation-key        yi     cooks
# 38     Zhou2025 -2.251240  0.288769
# 27       Wu2025  2.353985  0.184419
# 10      Xie2025  1.753006  0.115315
# 28     Wynn2025 -0.542540  0.091620
# 22   Ferber2025  2.411784  0.046341
#
# Top 5 hat values:
#    citation-key        yi       hat
# 21      Bao2025  0.136625  0.028625
# 28     Wynn2025 -0.542540  0.028613
# 30      Lin2025  0.452201  0.028608
# 37      Liu2026  0.194300  0.028545
# 31      Cui2025  0.364627  0.028540

# %% [markdown]
# ## Subgroup Analysis

# %%
sg_task = subgroup_analysis(df, "task-category")
print("=== Subgroup by Task Category ===")
print(sg_task[["group", "k", "pooled-lor", "ci-lo", "ci-hi", "i2"]].to_string(index=False))
if "q-between" in sg_task.attrs:
    print(f"\nQ_between = {sg_task.attrs['q-between']:.2f}, df = {sg_task.attrs['df-between']}, p = {sg_task.attrs['p-between']:.4f}")
fig_sg_task = subgroup_forest(sg_task, "task-category")
plt.show()

sg_arch = subgroup_analysis(df, "architecture")
print("\n=== Subgroup by Architecture ===")
print(sg_arch[["group", "k", "pooled-lor", "ci-lo", "ci-hi", "i2"]].to_string(index=False))
if "q-between" in sg_arch.attrs:
    print(f"\nQ_between = {sg_arch.attrs['q-between']:.2f}, df = {sg_arch.attrs['df-between']}, p = {sg_arch.attrs['p-between']:.4f}")
fig_sg_arch = subgroup_forest(sg_arch, "architecture")
plt.show()
# Out:
# === Subgroup by Task Category ===
#             group  k  pooled-lor     ci-lo    ci-hi        i2
#              code 11    0.809744  0.477496 1.141991 77.465082
#        evaluation  3    0.239089  0.036272 0.441905  0.000000
# general-knowledge  3    0.015421 -0.559707 0.590549 99.661983
#              math  6    0.341564  0.126307 0.556822 94.768073
#           medical  7    0.419334  0.290668 0.548001 62.451538
#             other 10    0.309904 -0.429147 1.048955 91.382774
#
# Q_between = 10.32, df = 5, p = 0.0666
# === Subgroup by Architecture ===
#           group  k  pooled-lor     ci-lo    ci-hi        i2
#     cooperation  9    0.302281 -0.370252 0.974813 91.220648
#          debate 20    0.369485  0.164966 0.574004 98.364947
#       hierarchy  6    0.743852  0.240560 1.247145 89.067939
#       role-play  2    0.320175  0.054240 0.586109  0.000000
# verifier-critic  2    1.002798 -0.439186 2.444783 97.611249
#
# Q_between = 2.96, df = 4, p = 0.5643

# %% [markdown]
# ## Meta-Regression

# %%
mr_df = df.copy()
mr_df["year-centered"] = mr_df["year"] - mr_df["year"].mean()
mr_df["backbone-family"] = mr_df["backbone-model"].str.extract(r"(GPT|Claude|Llama|Gemini|Qwen|DeepSeek)", expand=False).fillna("other")
mr_cols = ["compute-parity-flag", "year-centered", "backbone-family", "n-agents"]
mr_df["n-agents"] = pd.to_numeric(mr_df["n-agents"], errors="coerce").fillna(3)

mr_results = meta_regression(mr_df, mr_cols)
print("=== Meta-Regression: yi ~ compute-parity + year + backbone-family + n-agents ===")
print(mr_results.round(4).to_string(index=False))
print(f"\nResidual τ² = {mr_results.attrs.get('tau2', 'N/A'):.4f}")
# Out:
# === Meta-Regression: yi ~ compute-parity + year + backbone-family + n-agents ===
#                        coef  estimate     se       z      p
#                   intercept    0.1190 0.8282  0.1437 0.8857
# compute-parity-flag_unclear    0.2824 0.2861  0.9873 0.3235
#     compute-parity-flag_yes    0.1171 0.2971  0.3942 0.6934
#               year-centered   -0.0253 0.1686 -0.1501 0.8807
#         backbone-family_GPT    0.2842 0.6019  0.4721 0.6369
#      backbone-family_Gemini    0.2355 0.6596  0.3570 0.7211
#        backbone-family_Qwen   -0.2501 0.6480 -0.3861 0.6995
#       backbone-family_other    0.0265 0.6276  0.0422 0.9663
#                    n-agents    0.0373 0.1991  0.1874 0.8513
#
# Residual τ² = 0.3208

# %% [markdown]
# ## Publication Bias

# %%
fig_funnel = funnel_plot(df, pooled)
plt.show()

egger = egger_test(yi, df["sei"].values)
print(f"Egger's test: intercept = {egger['intercept']:.3f}, t = {egger['t']:.3f}, p = {egger['p']:.4f}")

begg = begg_test(yi, vi)
print(f"Begg's test: τ = {begg['tau']:.3f}, p = {begg['p']:.4f}")

tf = trim_and_fill(yi, vi)
print(f"\nTrim-and-fill: {tf['k0']} studies imputed")
print(f"  Original pooled LOR: {tf['pooled-lor-orig']:.3f}")
print(f"  Adjusted pooled LOR: {tf['pooled-lor-adj']:.3f} [{tf['ci-lo-adj']:.3f}, {tf['ci-hi-adj']:.3f}]")

pc = p_curve(yi, df["sei"].values)
print(f"\nP-curve: {pc}")
# Out:
# Egger's test: intercept = 2.521, t = 31.637, p = 0.7624
# Begg's test: τ = 0.066, p = 0.5442
#
# Trim-and-fill: 0 studies imputed
#   Original pooled LOR: 0.443
#   Adjusted pooled LOR: 0.443 [0.255, 0.631]
#
# P-curve: {'n-sig': 28, 'n-right-skewed': 26, 'n-total': 28, 'prop-right': np.float64(0.9285714285714286), 'binom-p': np.float64(3.032386302947998e-06), 'evidential-value': np.True_}

# %% [markdown]
# ## Sensitivity Analyses

# %%
sens = run_all_sensitivity(df, rob)
print("=== Sensitivity Analyses ===")
print(sensitivity_table(sens))

loo = leave_one_out(yi, vi, pooled["tau2"])
loo["citation-key"] = df["citation-key"].values
print(f"\nLeave-one-out range: [{loo['mu'].min():.3f}, {loo['mu'].max():.3f}]")
most_influential = loo.loc[loo["mu"].idxmin()]
print(f"Most influential (lowest pooled when removed): {most_influential['citation-key']} → LOR={most_influential['mu']:.3f}")
# Out:
# === Sensitivity Analyses ===
# | label               |   k |   pooled-lor |   ci-lo |   ci-hi | i2   |
# |:--------------------|----:|-------------:|--------:|--------:|:-----|
# | Full sample         |  41 |         0.44 |    0.26 |    0.63 | 98%  |
# | Compute-parity only |   9 |         0.3  |    0.09 |    0.52 | 87%  |
# | 2025+ only          |  29 |         0.4  |    0.14 |    0.66 | 98%  |
# | High-RoB removed    |  16 |         0.42 |    0.18 |    0.66 | 93%  |
#
# Leave-one-out range: [0.402, 0.495]
# Most influential (lowest pooled when removed): Wu2025 → LOR=0.402

# %% [markdown]
# ## Frontier-Model Paradox

# %%
df["sa-accuracy"] = df["n-correct-sa"] / df["n-items"]
fig_bubble = bubble_plot(df, "sa-accuracy")
plt.show()

from scipy.stats import pearsonr
r, p = pearsonr(df["sa-accuracy"], df["yi"])
print(f"Correlation between SA baseline accuracy and MA advantage (log-OR):")
print(f"  r = {r:.3f}, p = {p:.4f}")
print(f"  Interpretation: {'Negative correlation supports frontier-model paradox' if r < 0 else 'No support for paradox in this sample'}")
# Out:
# Correlation between SA baseline accuracy and MA advantage (log-OR):
#   r = -0.183, p = 0.2534
#   Interpretation: Negative correlation supports frontier-model paradox

# %% [markdown]
# ## PRISMA Flow + Export

# %%
fig_prisma = prisma_flow(prisma_counts)
plt.show()

results_summary = {
    "reml": res_reml,
    "dl": res_dl,
    "egger": egger,
    "begg": begg,
    "trim-and-fill": tf,
    "p-curve": {k: (v if not isinstance(v, (np.integer, np.floating)) else float(v)) for k, v in pc.items()},
}
with open(REPORT_ASSETS / "results-summary.json", "w") as f:
    json.dump(results_summary, f, indent=2, default=float)

desc.to_csv(REPORT_ASSETS / "descriptives.csv")
sens.to_csv(REPORT_ASSETS / "sensitivity.csv", index=False)
sg_task.to_csv(REPORT_ASSETS / "subgroup-task.csv", index=False)
sg_arch.to_csv(REPORT_ASSETS / "subgroup-arch.csv", index=False)
mr_results.to_csv(REPORT_ASSETS / "meta-regression.csv", index=False)

print(f"All outputs exported to {REPORT_ASSETS}")
print(f"Figures: {[f.name for f in REPORT_ASSETS.glob('*.png')]}")
print(f"Data: {[f.name for f in REPORT_ASSETS.glob('*.csv')]}")
# Out:
# All outputs exported to /Users/veto/Library/CloudStorage/OneDrive-KULeuven/Courses/Meta Analysis/Proj-Meta/report/assets
# Figures: ['subgroup-task-category.png', 'funnel-plot.png', 'subgroup-architecture.png', 'forest-plot.png', 'prisma-flow.png', 'bubble-plot.png', 'baujat-plot.png']
# Data: ['descriptives.csv', 'subgroup-task.csv', 'meta-regression.csv', 'subgroup-arch.csv', 'sensitivity.csv']
